# %%
import numpy as np

# %%
my_list=[1,2,3,4,5]
narr=np.array(my_list)
narr
# Out:
# array([1, 2, 3, 4, 5])

# %%
npr=np.array([x*x for x in range(10)])
npr
# Out:
# array([ 0,  1,  4,  9, 16, 25, 36, 49, 64, 81])
