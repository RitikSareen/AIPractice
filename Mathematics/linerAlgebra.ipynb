# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
a = np.array([2, 3, 4])
b = np.array([1, 0, 5])

# %%
sum=0
for i in range(len(a)):
    sum = sum+(a[i]*b[i])

print(sum)
# Out:
# 22

# %%
a@b
# Out:
# np.int64(22)

# %%
np.dot(a,b)
# Out:
# np.int64(22)

# %%
v=np.array([3,4])

# %%
np.sqrt(np.sum([np.power(3,2),np.power(4 ,2)]))
# Out:
# np.float64(5.0)
